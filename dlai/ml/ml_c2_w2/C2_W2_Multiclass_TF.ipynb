# %% [markdown]
# # Optional Lab - Multi-class Classification

# %% [markdown]
# ## 1.1 Goals
# In this lab, you will explore an example of multi-class classification using neural networks.
# <figure>
#  <img src="./images/C2_W2_mclass_header.png"   style="width500px;height:200px;">
# </figure>

# %% [markdown]
# ## 1.2 Tools
# You will use some plotting routines. These are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)
# Out:
# 2024-02-26 15:10:17.636265: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# In this lab you will see an example of building a multiclass network in Tensorflow. We will then take a look at how the neural network makes its predictions.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
# <img align="Right" src="./images/C2_W2_mclass_lab_network.PNG"  style=" width:350px; padding: 10px 20px ; ">
# This lab will use a 2-layer network as shown.
# Unlike the binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 5ms/step - loss: 4.3495
# Epoch 2/200
# 4/4 [==============================] - 0s 15ms/step - loss: 3.9354
# Epoch 3/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.6220
# Epoch 4/200
# 4/4 [==============================] - 0s 15ms/step - loss: 3.2783
# Epoch 5/200
# 4/4 [==============================] - 0s 6ms/step - loss: 3.0248
# Epoch 6/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7792
# Epoch 7/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.5610
# Epoch 8/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3788
# Epoch 9/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.2152
# Epoch 10/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0859
# Epoch 11/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9592
# Epoch 12/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8462
# Epoch 13/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.7418
# Epoch 14/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6729
# Epoch 15/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5967
# Epoch 16/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.5381
# Epoch 17/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4883
# Epoch 18/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4425
# Epoch 19/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3988
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3583
# Epoch 21/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3217
# Epoch 22/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2861
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2480
# Epoch 24/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2142
# Epoch 25/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1785
# Epoch 26/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1450
# Epoch 27/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1112
# Epoch 28/200
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0791
# Epoch 29/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0462
# Epoch 30/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0155
# Epoch 31/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9855
# Epoch 32/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9567
# Epoch 33/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9305
# Epoch 34/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9054
# Epoch 35/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8810
# Epoch 36/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8587
# Epoch 37/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8383
# Epoch 38/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8193
# Epoch 39/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8006
# Epoch 40/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7836
# Epoch 41/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7674
# Epoch 42/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7534
# Epoch 43/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7401
# Epoch 44/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7269
# Epoch 45/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7150
# Epoch 46/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7024
# Epoch 47/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6921
# Epoch 48/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6812
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6704
# Epoch 50/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6604
# Epoch 51/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6512
# Epoch 52/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6416
# Epoch 53/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6325
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6243
# Epoch 55/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6159
# Epoch 56/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6079
# Epoch 57/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6001
# Epoch 58/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5924
# Epoch 59/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5849
# Epoch 60/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5774
# Epoch 61/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5702
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5625
# Epoch 63/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5558
# Epoch 64/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5486
# Epoch 65/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5429
# Epoch 66/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5361
# Epoch 67/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5299
# Epoch 68/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5233
# Epoch 69/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5157
# Epoch 70/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5101
# Epoch 71/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5032
# Epoch 72/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4968
# Epoch 73/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4907
# Epoch 74/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4842
# Epoch 75/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4778
# Epoch 76/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4719
# Epoch 77/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4644
# Epoch 78/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4563
# Epoch 79/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4471
# Epoch 80/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4383
# Epoch 81/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4291
# Epoch 82/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4162
# Epoch 83/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4022
# Epoch 84/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3878
# Epoch 85/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3707
# Epoch 86/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3546
# Epoch 87/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3390
# Epoch 88/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3231
# Epoch 89/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3054
# Epoch 90/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2893
# Epoch 91/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2736
# Epoch 92/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2607
# Epoch 93/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2469
# Epoch 94/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2344
# Epoch 95/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2236
# Epoch 96/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2143
# Epoch 97/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2052
# Epoch 98/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1956
# Epoch 99/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1879
# Epoch 100/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1794
# Epoch 101/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1732
# Epoch 102/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1672
# Epoch 103/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1607
# Epoch 104/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1542
# Epoch 105/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1487
# Epoch 106/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1436
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1388
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1344
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1307
# Epoch 110/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1270
# Epoch 111/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1237
# Epoch 112/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1206
# Epoch 113/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1177
# Epoch 114/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1149
# Epoch 115/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1121
# Epoch 116/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1096
# Epoch 117/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1069
# Epoch 118/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1047
# Epoch 119/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1025
# Epoch 120/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1004
# Epoch 121/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0983
# Epoch 122/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0962
# Epoch 123/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0942
# Epoch 124/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0921
# Epoch 125/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0905
# Epoch 126/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0883
# Epoch 127/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0865
# Epoch 128/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0848
# Epoch 129/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0832
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0816
# Epoch 131/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0802
# Epoch 132/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0787
# Epoch 133/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0773
# Epoch 134/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0759
# Epoch 135/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0746
# Epoch 136/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0732
# Epoch 137/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0719
# Epoch 138/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0707
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0696
# Epoch 140/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0684
# Epoch 141/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0674
# Epoch 142/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0664
# Epoch 143/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0654
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0645
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0635
# Epoch 146/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0625
# Epoch 147/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0616
# Epoch 148/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0607
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0599
# Epoch 150/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0591
# Epoch 151/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0583
# Epoch 152/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0574
# Epoch 153/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0567
# Epoch 154/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0560
# Epoch 155/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0551
# Epoch 156/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0544
# Epoch 157/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0537
# Epoch 158/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0529
# Epoch 159/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0522
# Epoch 160/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0515
# Epoch 161/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0509
# Epoch 162/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0501
# Epoch 163/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0494
# Epoch 164/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0487
# Epoch 165/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0483
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0476
# Epoch 167/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0471
# Epoch 168/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0465
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0459
# Epoch 170/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0454
# Epoch 171/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0448
# Epoch 172/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0443
# Epoch 173/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0438
# Epoch 174/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0432
# Epoch 175/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0427
# Epoch 176/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0422
# Epoch 177/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0417
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0412
# Epoch 179/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0409
# Epoch 180/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0404
# Epoch 181/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0399
# Epoch 182/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0395
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0391
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0388
# Epoch 185/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0384
# Epoch 186/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0380
# Epoch 187/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0376
# Epoch 188/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0373
# Epoch 189/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0369
# Epoch 190/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0366
# Epoch 191/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0362
# Epoch 192/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0358
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0354
# Epoch 194/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0351
# Epoch 195/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0347
# Epoch 196/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0343
# Epoch 197/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0340
# Epoch 198/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0337
# Epoch 199/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0333
# Epoch 200/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0330

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 1s 2ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. How did it accomplish this? Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results. You don't need to know these details to successfully use neural networks, but it may be helpful to gain more intuition about how the layers combine to solve a classification problem.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
# #### Layer 1 <img align="Right" src="./images/C2_W2_mclass_layer1.png"  style=" width:600px; padding: 10px 20px ; ">
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. Recall the graph for a ReLu :<img align="right" src="./images/C2_W2_mclass_relu.png"  style=" width:200px; padding: 10px 20px ; "> The contour line in the graph is the inflection point in the ReLu.
#
# Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer  <img align="Right" src="./images/C2_W2_mclass_layer2.png"  style=" width:600px; padding: 10px 20px ; ">
#
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
#
# You can successfully use neural networks without knowing the details of what each unit is up to. Hopefully, this example has provided some intuition about what is happening under the hood.

# %% [markdown]
# ## Congratulations!
# You have learned to build and operate a neural network for multiclass classification.
